# %%
##================================================
## このセルを最初に実行せよ---Run this cell first.
##================================================
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Out:
# --2025-12-19 08:02:30--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1779 (1.7K) [text/plain]
# Saving to: ‘./text-sample.txt’
#
# text-sample.txt     100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2025-12-19 08:02:31 (4.98 MB/s) - ‘./text-sample.txt’ saved [1779/1779]
#
# --2025-12-19 08:02:31--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27681 (27K) [application/octet-stream]
# Saving to: ‘./tokyo-temps.csv’
#
# tokyo-temps.csv     100%[===================>]  27.03K  --.-KB/s    in 0.002s
#
# 2025-12-19 08:02:31 (10.8 MB/s) - ‘./tokyo-temps.csv’ saved [27681/27681]
#
# --2025-12-19 08:02:31--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘./small.csv’
#
# small.csv           100%[===================>]      45  --.-KB/s    in 0s
#
# 2025-12-19 08:02:31 (687 KB/s) - ‘./small.csv’ saved [45/45]
#
# --2025-12-19 08:02:31--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1562 (1.5K) [text/plain]
# Saving to: ‘./tokyo-july-temps.csv’
#
# tokyo-july-temps.cs 100%[===================>]   1.53K  --.-KB/s    in 0s
#
# 2025-12-19 08:02:31 (27.7 MB/s) - ‘./tokyo-july-temps.csv’ saved [1562/1562]
#
# --2025-12-19 08:02:31--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘./argsprint.py’
#
# argsprint.py        100%[===================>]      27  --.-KB/s    in 0s
#
# 2025-12-19 08:02:31 (532 KB/s) - ‘./argsprint.py’ saved [27/27]
#
# --2025-12-19 08:02:31--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34029 (33K) [text/plain]
# Saving to: ‘./B1S.xml’
#
# B1S.xml             100%[===================>]  33.23K  --.-KB/s    in 0.002s
#
# 2025-12-19 08:02:32 (15.9 MB/s) - ‘./B1S.xml’ saved [34029/34029]
#
# --2025-12-19 08:02:32--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46 [text/plain]
# Saving to: ‘./sample.py’
#
# sample.py           100%[===================>]      46  --.-KB/s    in 0s
#
# 2025-12-19 08:02:32 (767 KB/s) - ‘./sample.py’ saved [46/46]
#
# --2025-12-19 08:02:32--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8568 (8.4K) [text/plain]
# Saving to: ‘./sin.html’
#
# sin.html            100%[===================>]   8.37K  --.-KB/s    in 0s
#
# 2025-12-19 08:02:32 (88.3 MB/s) - ‘./sin.html’ saved [8568/8568]
#
# --2025-12-19 08:02:32--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39759 (39K) [image/png]
# Saving to: ‘fig/console_in_browser.png’
#
# console_in_browser. 100%[===================>]  38.83K  --.-KB/s    in 0.002s
#
# 2025-12-19 08:02:32 (15.6 MB/s) - ‘fig/console_in_browser.png’ saved [39759/39759]
#
# --2025-12-19 08:02:32--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71665 (70K) [image/png]
# Saving to: ‘fig/sample_py_win_1.png’
#
# sample_py_win_1.png 100%[===================>]  69.99K  --.-KB/s    in 0.01s
#
# 2025-12-19 08:02:32 (6.48 MB/s) - ‘fig/sample_py_win_1.png’ saved [71665/71665]
#
# --2025-12-19 08:02:32--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22452 (22K) [image/png]
# Saving to: ‘fig/sample_py_win_3.png’
#
# sample_py_win_3.png 100%[===================>]  21.93K  --.-KB/s    in 0.001s
#
# 2025-12-19 08:02:33 (15.9 MB/s) - ‘fig/sample_py_win_3.png’ saved [22452/22452]
#
# --2025-12-19 08:02:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11249 (11K) [image/png]
# Saving to: ‘fig/sample_py_win_2.png’
#
# sample_py_win_2.png 100%[===================>]  10.99K  --.-KB/s    in 0.001s
#
# 2025-12-19 08:02:33 (16.7 MB/s) - ‘fig/sample_py_win_2.png’ saved [11249/11249]
#
# --2025-12-19 08:02:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22815 (22K) [image/png]
# Saving to: ‘fig/py_open_2.png’
#
# py_open_2.png       100%[===================>]  22.28K  --.-KB/s    in 0.002s
#
# 2025-12-19 08:02:33 (12.3 MB/s) - ‘fig/py_open_2.png’ saved [22815/22815]
#
# --2025-12-19 08:02:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36596 (36K) [image/png]
# Saving to: ‘fig/py_open_1.png’
#
# py_open_1.png       100%[===================>]  35.74K  --.-KB/s    in 0.002s
#
# 2025-12-19 08:02:33 (16.3 MB/s) - ‘fig/py_open_1.png’ saved [36596/36596]
#
# --2025-12-19 08:02:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7800 (7.6K) [image/png]
# Saving to: ‘fig/sample_py_mac_2.png’
#
# sample_py_mac_2.png 100%[===================>]   7.62K  --.-KB/s    in 0s
#
# 2025-12-19 08:02:33 (66.3 MB/s) - ‘fig/sample_py_mac_2.png’ saved [7800/7800]
#
# --2025-12-19 08:02:33--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21366 (21K) [image/png]
# Saving to: ‘fig/sample_py_mac_3.png’
#
# sample_py_mac_3.png 100%[===================>]  20.87K  --.-KB/s    in 0.001s
#
# 2025-12-19 08:02:34 (16.0 MB/s) - ‘fig/sample_py_mac_3.png’ saved [21366/21366]
#
# --2025-12-19 08:02:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54233 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_1.png’
#
# sample_py_win2_1.pn 100%[===================>]  52.96K  --.-KB/s    in 0.006s
#
# 2025-12-19 08:02:34 (8.63 MB/s) - ‘fig/sample_py_win2_1.png’ saved [54233/54233]
#
# --2025-12-19 08:02:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10214 (10.0K) [image/png]
# Saving to: ‘fig/sample_py_win2_3.png’
#
# sample_py_win2_3.pn 100%[===================>]   9.97K  --.-KB/s    in 0s
#
# 2025-12-19 08:02:34 (22.1 MB/s) - ‘fig/sample_py_win2_3.png’ saved [10214/10214]
#
# --2025-12-19 08:02:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238677 (233K) [image/png]
# Saving to: ‘fig/sample_py_mac_1.png’
#
# sample_py_mac_1.png 100%[===================>] 233.08K  --.-KB/s    in 0.02s
#
# 2025-12-19 08:02:34 (13.7 MB/s) - ‘fig/sample_py_mac_1.png’ saved [238677/238677]
#
# --2025-12-19 08:02:34--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54719 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_2.png’
#
# sample_py_win2_2.pn 100%[===================>]  53.44K  --.-KB/s    in 0.008s
#
# 2025-12-19 08:02:35 (6.51 MB/s) - ‘fig/sample_py_win2_2.png’ saved [54719/54719]
#
# --2025-12-19 08:02:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17101 (17K) [image/png]
# Saving to: ‘fig/argsprint.png’
#
# argsprint.png       100%[===================>]  16.70K  --.-KB/s    in 0.001s
#
# 2025-12-19 08:02:35 (24.3 MB/s) - ‘fig/argsprint.png’ saved [17101/17101]
#
# --2025-12-19 08:02:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12461 (12K) [image/png]
# Saving to: ‘fig/terminal_in_menu.png’
#
# terminal_in_menu.pn 100%[===================>]  12.17K  --.-KB/s    in 0s
#
# 2025-12-19 08:02:35 (87.0 MB/s) - ‘fig/terminal_in_menu.png’ saved [12461/12461]
#
# --2025-12-19 08:02:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58231 (57K) [image/png]
# Saving to: ‘fig/sample_py_browser.png’
#
# sample_py_browser.p 100%[===================>]  56.87K  --.-KB/s    in 0.006s
#
# 2025-12-19 08:02:35 (8.61 MB/s) - ‘fig/sample_py_browser.png’ saved [58231/58231]
#
# --2025-12-19 08:02:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27636 (27K) [image/png]
# Saving to: ‘fig/py_conv_1.png’
#
# py_conv_1.png       100%[===================>]  26.99K  --.-KB/s    in 0.002s
#
# 2025-12-19 08:02:35 (13.4 MB/s) - ‘fig/py_conv_1.png’ saved [27636/27636]
#
# --2025-12-19 08:02:35--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59488 (58K) [image/png]
# Saving to: ‘fig/py_conv_2.png’
#
# py_conv_2.png       100%[===================>]  58.09K  --.-KB/s    in 0.008s
#
# 2025-12-19 08:02:36 (7.16 MB/s) - ‘fig/py_conv_2.png’ saved [59488/59488]

# %% [markdown]
# # ▲CSVファイルの入出力
# CSVファイルの入出力について説明します。
#
# 参考
#
# - https://docs.python.org/ja/3/library/csv.html
#
# ## CSV形式とは
#
# **CSV**形式とは "comma-separated values" の略で、
# 複数の値をコンマで区切って記録するファイル形式です。
#
# みなさんExcelを使ったことがあると思いますが、
# Excelでは1つのセルに1つの値（数値や文字など）が入っていて、
# その他のセルの値とは独立に扱えますよね。
#
# それと同じように、CSV形式では、`,`（コンマ）で区切られた要素はそれぞれ独立の値として扱われます。
#
# たとえばサークルのメンバーデータを作ることを考えましょう。
# メンバーは「鈴木一郎」と「山田花子」の2名で、
# それぞれ『氏名』『ニックネーム』『出身地』を記録しておきたいと思います。
#
# 表で表すとこんなデータです。
#
# |ID| 氏名 | ニックネーム | 出身地 |
# |---:|:--------|:---------------|:-------|
# |user1| 鈴木一郎 | イチロー | 広島 |
# |user2| 山田花子 | はなこ | 名古屋 |
#
# これをCSV形式で表すと次のようになります。

# %% [raw]
# 'user1','鈴木一郎','イチロー','広島'
# 'user2','山田花子','はなこ','名古屋'

# %% [markdown]
# ## CSVファイルの読み込み
# CSVファイルを読み書きするには、
# ファイルをオープンして、そのファイルオブジェクトから、
# CSVリーダを作ります。
#
# **CSVリーダ**とは、CSVファイルからデータを読み込むためのオブジェクトで、
# このオブジェクトのメソッドを呼び出すことにより、CSVファイルからデータを読み込むことができます。
#
# CSVリーダを作るには、
# **`csv`** というモジュールの **`csv.reader`** という関数にファイルオブジェクトを渡します。
#
# たとえば、次のような表で表されるCSVファイル `small.csv` を読み込んでみましょう。
#
#  0列目 | 1列目 | 2列目 | 3列目 | 4列目
# ---|---|---|---|---
#  11 | 12 | 13 | 14 | 15
#  21 | 22 | 23 | 24 | 25
#  31 | 32 | 33 | 34 | 35

# %%
import csv
f = open('small.csv', 'r')
dataReader = csv.reader(f)

# %% [markdown]
# このオブジェクトもイテレータで、`next` という関数を呼び出すことができます。

# %%
next(dataReader)

# %% [markdown]
# このようにして CSVファイルを読むと、
# CSVファイルの各行のデータが文字列のリストとなって返されます。

# %%
next(dataReader)

# %%
row = next(dataReader)

# %%
row

# %%
row[2]

# %% [markdown]
# 数値が `''` で囲われている場合、数値ではなく文字列として扱われているので、そのまま計算に使用することができません。
#
# 文字列が整数を表す場合、**`int`** 関数によって文字列を整数に変換することができます。
# 文字列が小数を含む場合は **`float`** 関数で浮動小数点数型に変換、文字列が複素数を表す場合は **`complex`** 関数で複素数に変換します。

# %%
int(row[2])

# %% [markdown]
# ファイルの終わりまで達した後に `next` 関数を実行すると、下のようにエラーが返ってきます。

# %%
next(dataReader)

# %% [markdown]
# ファイルを使い終わったらクローズすることを忘れないようにしましょう。

# %%
f.close()

# %% [markdown]
# ## CSVファイルに対するfor文
# CSVリーダもイテレータですので、for文の `in` の後に書くことができます。
#
# ---
# ```Python
# for row in dataReader:
#     ...
# ```
# ---
#
# 繰り返しの各ステップで、`next(dataReader)` が呼び出されて、
# `row` にその値が設定され、for文の中身が実行されます。

# %%
f = open('small.csv', 'r')
dataReader = csv.reader(f)
for row in dataReader:
    print(row)
f.close()

# %% [markdown]
# ## CSVファイルに対するwith文
# 以下はwith文を使った例です。

# %%
with open('small.csv', 'r') as f:
    dataReader = csv.reader(f)
    for row in dataReader:
        print(row)

# %% [markdown]
# ## CSVファイルの書き込み

# %% [markdown]
# CSVファイルを作成して書き込むには、CSVライターを作ります。
#
# **CSVライター**とは、CSVファイルを作ってデータを書き込むためのオブジェクトで、
# このオブジェクトのメソッドを呼び出すことにより、データがCSV形式でファイルに書き込まれます。
#
# CSVライターを作るには、
# **`csv`** というモジュールの **`csv.writer`** という関数にファイルオブジェクトを渡します。
# ここで、半角英数文字以外の文字（たとえば日本語文字や全角英数文字）を書き込み・書き出しする際には、
# 文字コード（たとえば `encoding='utf-8'`）を指定し、
# また書き出しの際にはさらに改行コードとして `newline=''` を指定しないと文字化けが生じる可能性があります。

# %%
f = open('out.csv', 'w', encoding='utf-8', newline='')

# %%
dataWriter = csv.writer(f)

# %%
dir(dataWriter)

# %%
dataWriter.writerow([1,2,3])

# %%
dataWriter.writerow([21,22,23])

# %% [markdown]
# 書き込みモードの場合も、ファイルを使い終わったらクローズすることを忘れないようにしましょう。

# %%
f.close()

# %% [markdown]
# 読み込みのときと同様、with文を使うこともできます。

# %%
with open('out.csv', 'w', encoding='utf-8', newline='') as f:
    dataWriter = csv.writer(f)
    dataWriter.writerow([1,2,3])
    dataWriter.writerow([21,22,23])

# %% [markdown]
# ### 東京の7月の気温
# `tokyo-temps.csv` には、気象庁のオープンデータからダウンロードした、
# 東京の7月の平均気温のデータが入っています。
#
# http://www.data.jma.go.jp/gmd/risk/obsdl/
#
# 48行目の第2列に1875年7月の平均気温が入っており、
# 以下、2016年まで、12行ごとに7月の平均気温が入っています。

# %% [markdown]
# 以下は、これを取り出すPythonの簡単なコードです。

# %%
import csv

with open('tokyo-temps.csv', 'r', encoding='shift_jis') as f:
    dataReader = csv.reader(f) # csvリーダを作成
    n=0
    year = 1875
    years = []
    july_temps = []
    for row in dataReader: # CSVファイルの中身を1行ずつ読み込み
        n = n+1
        if n>=48 and (n-48)%12 == 0: # 48行目からはじめて12か月ごとにif内を実行
            years.append(year)
            july_temps.append(float(row[1]))
            year = year + 1

# %% [markdown]
# ファイルをオープンするときに、キーワード引数の **`encoding`** が指定されています。
# このファイルはShift_JISという文字コードで書かれているため、
# この引数で、ファイルの符号（**文字コード**）を指定します。
# `'shift_jis'` はShift_JISを意味します。この他に、`'utf-8'`（UTF-8、すなわちビットのUnicode）があります。

# %% [markdown]
# 変数 `years` に年の配列、変数 `july_temps` に対応する年の7月の平均気温の配列が設定されます。

# %%
years

# %%
july_temps

# %% [markdown]
# ここでは詳しく説明しませんが、**線形回帰**によるフィッティングを行ってみましょう。

# %%
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

fitp = numpy.poly1d(numpy.polyfit(years, july_temps, 1))
ma = max(years)
mi = min(years)
xp = numpy.linspace(mi, ma, (ma - mi))

# %%
plt.plot(years, july_temps, '.', xp, fitp(xp), '-')
plt.show()

# %% [markdown]
# ## 練習
#
# 1. `tokyo-temps.csv` を読み込んで、各行が西暦年と7月の気温のみからなる `'tokyo-july-temps.csv'` という名前のCSVファイルを作成してください。
# 西暦年は1875から2016までとします。
#
# 2. 作成したCSVファイルをExcelで読み込むとどうなるか確認してください。

# %% [markdown]
# 以下のセルによってテストしてください。（`years` と `july_temps` の値がそのままと仮定しています。）

# %%
with open('tokyo-july-temps.csv', 'r', encoding='shift_jis') as f:
    i = 0
    dataReader = csv.reader(f)
    for row in dataReader:
        if int(row[0]) != years[i] or abs(float(row[1])-july_temps[i])>0.000001:
            print('error', int(row[0]), float(row[1]))
        i += 1
print(i== 142) # 1875年から2016年まで142年間分のデータがあるはずです

# %% [markdown]
# ## 練習
#
# 整数データのみからなるCSVファイルの名前を受け取ると、そのCSVファイルの各行を読み込んで整数のリストを作り、
# ファイル全体の内容を、そのようなリストのリストとして返す関数 `csv_matrix(name)` を定義してください。
#
# たとえば上で用いた `small.csv` には次のようなデータが入っています。
#
#
#  0列目 | 1列目 | 2列目 | 3列目 | 4列目
# ---|---|---|---|---
#  11 | 12 | 13 | 14 | 15
#  21 | 22 | 23 | 24 | 25
#  31 | 32 | 33 | 34 | 35
#
# この `small.csv` の名前が引数として与えられた場合、
#
# ```Python
# [[11, 12, 13, 14, 15], [21, 22, 23, 24, 25], [31, 32, 33, 34, 35]]
# ```
#
# というリストを返します。

# %%
def csv_matrix(name):
    ...

# %% [markdown]
# 以下のセルによってテストしてください。

# %%
print(csv_matrix('small.csv') == [[11, 12, 13, 14, 15], [21, 22, 23, 24, 25], [31, 32, 33, 34, 35]])

# %% [markdown]
# ## 練習の解答

# %%
with open('tokyo-july-temps.csv', 'w', encoding='utf-8', newline='') as f:
    i = 0
    dataWriter = csv.writer(f)
    for i in range(len(years)):
        dataWriter.writerow([years[i],july_temps[i]])

# %%
def csv_matrix(name):
    rows = []
    with open(name, 'r') as f:
        dataReader = csv.reader(f)
        for row in dataReader:
            rows.append([int(x) for x in row])
    return rows

# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
#
# # 定数定義
# Gt_dB = 10; Gr_dB = 5  # アンテナ利得 [dB]
# Pt_W = 0.1             # 送信電力 100mW [6]
# d = 500                # 伝送距離 500m
# k = 1.38e-23           # ボルツマン定数
# T = 600                # 雑音温度 600K
# B = 6e6                # 帯域幅 6MHz
# c = 3e8                # 光速度
#
# # 周波数設定: 0.5GHzから10GHzまで500MHz刻み
# f = np.arange(0.5e9, 10.5e9, 0.5e9)
#
# # 利得を真数に変換
# Gt = 10**(Gt_dB/10); Gr = 10**(Gr_dB/10)
#
# # 計算
# Pn = k * T * B         # 雑音電力（真値）
# lam = c / f            # 波長
# Lp = (4 * np.pi * d / lam)**2 # 自由空間損失（真値）
# Pr = (Pt_W * Gt * Gr) / Lp    # 受信電力（真値）
# SNR = Pr / Pn          # SN比（真値）
#
# # プロット
# plt.semilogx(f, SNR, 'o-')
# plt.xlabel('Frequency [Hz]')
# plt.ylabel('SNR (Linear Value)')
# plt.title('Frequency vs SNR')
# plt.grid(True, which="both", ls="-")
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定数定義
Gt_dB = 10; Gr_dB = 5  # アンテナ利得 [dB]
Pt_W = 0.1             # 送信電力 100mW [6]
d = 500                # 伝送距離 500m
k = 1.38e-23           # ボルツマン定数
T = 600                # 雑音温度 600K
B = 6e6                # 帯域幅 6MHz
c = 3e8                # 光速度

# 周波数設定: 0.5GHzから10GHzまで500MHz刻み
f = np.arange(0.5e9, 10.5e9, 0.5e9)

# 利得を真数に変換
Gt = 10**(Gt_dB/10); Gr = 10**(Gr_dB/10)

# 計算
Pn = k * T * B         # 雑音電力（真値）
lam = c / f            # 波長
Lp = (4 * np.pi * d / lam)**2 # 自由空間損失（真値）
Pr = (Pt_W * Gt * Gr) / Lp    # 受信電力（真値）
SNR = Pr / Pn          # SN比（真値）

# プロット
plt.semilogx(f, SNR, 'o-')
plt.xlabel('Frequency [Hz]')
plt.ylabel('SNR (Linear Value)')
plt.title('Frequency vs SNR')
plt.grid(True, which="both", ls="-")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 設定: Wi-Fi 2.4GHz
f = 2.412e9
c = 3e8
lam = c / f
k = 2 * np.pi / lam
d = lam / 4             # 素子間隔
psi = -k * d            # 位相差 [9]
N = 7                   # 素子数

theta = np.linspace(0, 2*np.pi, 361)

# アレー係数の計算
# arg = (k * d * np.cos(theta) + psi) / 2
# 分母が0になるのを防ぐため極限を考慮するか、微小値を足す
psi_total = k * d * np.cos(theta) + psi
AF = np.abs(np.sin(N * psi_total / 2) / np.sin(psi_total / 2))
AF = AF / np.max(AF)    # 正規化

# プロット
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, AF)
ax.set_title("7-element End-fire Array Pattern (Wi-Fi 2.4GHz)")
plt.show()
# Out:
# /tmp/ipython-input-652613606.py:19: RuntimeWarning: invalid value encountered in divide
#   AF = np.abs(np.sin(N * psi_total / 2) / np.sin(psi_total / 2))

# %%
import numpy as np
import matplotlib.pyplot as plt

# パラメータ設定 [16]
ZL = 75.0; Zs = 50.0
L1_val = 71.6e-3; L2_val = 58.4e-3
R1=4.40; L1=3.06e-7; G1=3.73e-2; C1=1.21e-10
R2=9.69; L2=3.68e-7; G2=3.02e-2; C2=9.80e-11

f = np.linspace(10e6, 3e9, 300)
ReturnLoss = []

for fi in f:
    w = 2 * np.pi * fi
    # 線路1
    Zse1 = R1 + 1j*w*L1; Ysh1 = G1 + 1j*w*C1
    gamma1 = np.sqrt(Zse1 * Ysh1); Z01 = np.sqrt(Zse1 / Ysh1)
    F1 = np.matrix([[np.cosh(gamma1*L1_val), Z01*np.sinh(gamma1*L1_val)],
                    [(1/Z01)*np.sinh(gamma1*L1_val), np.cosh(gamma1*L1_val)]])
    # 線路2
    Zse2 = R2 + 1j*w*L2; Ysh2 = G2 + 1j*w*C2
    gamma2 = np.sqrt(Zse2 * Ysh2); Z02 = np.sqrt(Zse2 / Ysh2)
    F2 = np.matrix([[np.cosh(gamma2*L2_val), Z02*np.sinh(gamma2*L2_val)],
                    [(1/Z02)*np.sinh(gamma2*L2_val), np.cosh(gamma2*L2_val)]])

    F = F1 * F2
    # Zin = (F*ZL + F[17]) / (F[17]*ZL + F[17]) # Original erroneous line
    Zin = (F[0, 0]*ZL + F[0, 1]) / (F[1, 0]*ZL + F[1, 1]) # Corrected line using ABCD parameters
    gamma = (Zin - Zs) / (Zin + Zs)
    ReturnLoss.append(-20 * np.log10(np.abs(gamma)))

plt.plot(f/1e6, ReturnLoss)
plt.xlabel('Frequency [MHz]'); plt.ylabel('Return Loss [dB]')
plt.grid(True); plt.show()
